# %%
from collections import defaultdict
import os
import requests
import time

from bs4 import BeautifulSoup as BS
import simplejson as json
from tenacity import retry, stop_after_attempt, wait_random
from wos import WosClient
import wos.utils

# %%
session = requests.Session()
headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6",
    "Connection": "keep-alive",
    "Referer": "https://www.google.com.tw/",
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) "\
                  "Chrome/69.0.3497.92 Safari/537.36"
}

# %%
os.makedirs('data/author_to_articles',exist_ok=True)

# %%
import glob

article_infos = []
uidlist = glob.glob('data/uid_to_article/*.json')

for uid_n, uid in enumerate(uidlist, 1):
    if uid_n % 1000 == 0:
        print(f'Reading Article ID = {uid_n} to Construct Author List')

    with open(uid, 'r') as f:
        article_info = json.load(f)
        article_infos.append(article_info)
# Out:
# Reading Article ID = 1000 to Construct Author List
# Reading Article ID = 2000 to Construct Author List
# Reading Article ID = 3000 to Construct Author List
# Reading Article ID = 4000 to Construct Author List
# Reading Article ID = 5000 to Construct Author List
# Reading Article ID = 6000 to Construct Author List
# Reading Article ID = 7000 to Construct Author List
# Reading Article ID = 8000 to Construct Author List
# Reading Article ID = 9000 to Construct Author List
# Reading Article ID = 10000 to Construct Author List
# Reading Article ID = 11000 to Construct Author List
# Reading Article ID = 12000 to Construct Author List
# Reading Article ID = 13000 to Construct Author List

# %%
authors = list()
author_ids = set()
for article_info in article_infos:
    for author_name, author_id in zip(article_info['author_name'], article_info['author_id']):
        if author_id not in author_ids:
            author_ids.add(author_id)
            authors.append((author_name, author_id))
authors = sorted(set(authors))
print(f'There Are {len(authors)} Different Authors.')
# Out:
# There Are 11392 Different Authors.

# %%
@retry(stop=stop_after_attempt(3), 
       wait=wait_random(min=1, max=2))
def get_bsObj(url):
    try:
        req = session.get(url, headers=headers)
    except HTTPError:
        return None

    try:
        bsObj = BS(req.text, "html.parser")
    except AttributeError:
        return None
    return bsObj

# %%
@retry(stop=stop_after_attempt(3), 
       wait=wait_random(min=1, max=2))
def get_sum_with_uid(article_uid, client):
    article_bs = BS(client.retrieveById(article_uid).records, 'html.parser')
    summary = article_bs.find('summary')
    return extract_metadata_from_summary(summary)

# %%
@retry(stop=stop_after_attempt(3), 
       wait=wait_random(min=1, max=2))
def get_refs_with_uid(article_uid, client):
    
    refs = client.citedReferences(article_uid)
    refQueryId, refRecordsFound = refs.queryId, refs.recordsFound

    ref_meta_list = []
    for j in range(1, refRecordsFound+1, 100):
        if j != 1:
            time.sleep(2)
        ref_r = wc.citedReferencesRetrieve(refQueryId, count=min(100, refRecordsFound+1-j), offset=j)
        ref_meta_list.extend([dict(ref) for ref in ref_r])
    return ref_meta_list

# %%
@retry(stop=stop_after_attempt(3), 
       wait=wait_random(min=1, max=2))
def get_inv_refs_with_uid(article_uid, client):
    cits = wc.citingArticles(article_uid)
    citRecordsFound = cits.recordsFound
    
    inv_ref_meta_list = []
    for j in range(1, citRecordsFound+1, 100):
        if j != 1:
            time.sleep(2)
        inv_refs = wc.citingArticles(article_uid, count=min(100, citRecordsFound+1-j), offset=j)
        inv_refs = BS(inv_refs.records, 'html.parser')
        inv_ref_summaries = inv_refs.findAll('summary')
        inv_ref_meta_list.extend([extract_metadata_from_summary(inv_ref_summary) for inv_ref_summary in inv_ref_summaries])
    return inv_ref_meta_list

# %%
def extract_metadata_from_summary(summary):
#     print(summary.find('title', type='item').text)
    return {
        'title': summary.find('title', type='item').text,
        'author_name': [author.text for author in summary.findAll('wos_standard')],
        'author_id': [author.get('daisng_id') for author in summary.findAll('name', role='author')],
        'pubyear': summary.find('pub_info')['pubyear']
    }

# %%
import re

crawled_authors = glob.glob('data/author_to_articles/*.json')
crawled_authors = set([os.path.basename(filename).split('.')[0] for filename in crawled_authors])
print(f'There Are {len(crawled_authors)} Collected Authors. Remain {len(authors) - len(crawled_authors)} Authors.')
remained_authors = [author for author in authors if author[1] not in crawled_authors]

wc = WosClient()
wc.connect()
for author_order, (author_name, author_id) in enumerate(remained_authors, 1):
    
    print(f'Finding Articles of Author {author_order}: {author_name} ({author_id})')
    if author_order % 100 == 0:
        wc.close()
        wc = WosClient()
        wc.connect()

    query_url = "https://apps.webofknowledge.com/" + \
    f"InboundService.do?product=WOS&daisIds={author_id}" + \
    "&Func=Frame&DestFail=http%3A%2F%2Fwww.webofknowledge.com" + \
    f"&SrcApp=RRC&locale=zh_TW&SrcAuth=RRCPubList&SID={wc._SID}" + \
    "&customersID=RRCPubList&mode=SourceByDais&IsProductCode=Yes&Init=Yes&viewType=summary&action=search" + \
    "&action=changePageSize&pageSize=50"
    wos_codes = []
    
    while True:

        bsObj = get_bsObj(query_url)
        articles = bsObj.findAll('div', id=re.compile('^RECORD_[0-9]+$'))
        for article in articles:
            wos_url = article.find('div', class_='search-results-content').find('span', {'style': 'display: none'})['url']
            wos_code = [part for part in wos_url.split('&') if 'isickref=' in part]
            wos_code = wos_code[0].split('=')[1]
            wos_codes.append(wos_code)
#             print(wos_code)

        next_page_button = bsObj.find('a', class_='paginationNext snowplow-navigation-nextpage-top')
        if next_page_button is None:
            break
        
        next_page_url = next_page_button['href']
        query_url = next_page_url
    
    print(f'{len(wos_codes)} Articles Found.')
    
    
    with open(f'data/author_to_articles/{author_id}.json', 'w') as f:
        dump_data = {
            'author_id': author_id,
            'author_name': author_name,
            'uids': wos_codes
        }
        json.dump(dump_data, f, indent=4)

wc.close()
# Out:
# There Are 1299 Collected Authors. Remain 10093 Authors.
# b'Authenticated (SID: D4OFuCsgaukKWgR1eYF)'
# Finding Articles of Author 1: Bshary, R (169766)
# 185 Articles Found.
# Finding Articles of Author 2: Bub, D (230043)
# 112 Articles Found.
# Finding Articles of Author 3: Bucciarelli, M (1058260)
# 42 Articles Found.
# Finding Articles of Author 4: Buchman, AS (82442)
# 268 Articles Found.
# Finding Articles of Author 5: Buchmann, AF (715693)
# 67 Articles Found.
# Finding Articles of Author 6: Buchner, S (2305168)
# 28 Articles Found.
# Finding Articles of Author 7: Buchsbaum, B (656559)
# 69 Articles Found.
# Finding Articles of Author 8: Buchsbaum, D (3588186)
# 17 Articles Found.
# Finding Articles of Author 9: Buchtel, EE (40109539)
# 4 Articles Found.
# Finding Articles of Author 10: Buck, JL (485663)
# 108 Articles Found.
# Finding Articles of Author 11: Buck, R (35817900)
# 110 Articles Found.
# Finding Articles of Author 12: Buck, RW (129900)
# 18 Articles Found.
# Finding Articles of Author 13: Buckhalt, JA (564819)
# 83 Articles Found.
# Finding Articles of Author 14: Buckingham, G (1021408)
# 57 Articles Found.
# Finding Articles of Author 15: Buckingham, JT (2964147)
# 11 Articles Found.
# Finding Articles of Author 16: Buckner, C (2736467)
# 21 Articles Found.
# Finding Articles of Author 17: Buckner, RL (51004)
# 335 Articles Found.
# Finding Articles of Author 18: Buckwalter, W (1621801)
# 32 Articles Found.
# Finding Articles of Author 19: Budd, D (3890363)
# 18 Articles Found.
# Finding Articles of Author 20: Buder, EH (1405223)
# 41 Articles Found.
# Finding Articles of Author 21: Budescu, D (35809881)
# 121 Articles Found.
# Finding Articles of Author 22: Budwig, N (1544133)
# 14 Articles Found.
# Finding Articles of Author 23: Buetti, S (1938519)
# 34 Articles Found.
# Finding Articles of Author 24: Buettner, CK (1456944)
# 33 Articles Found.
# Finding Articles of Author 25: Bugmann, G (569279)
# 54 Articles Found.
# Finding Articles of Author 26: Bukach, C (1819380)
# 25 Articles Found.
# Finding Articles of Author 27: Bulbulia, J (540754)
# 82 Articles Found.
# Finding Articles of Author 28: Bulkeley, K (1145329)
# 39 Articles Found.
# Finding Articles of Author 29: Bulley, A (3506340)
# 23 Articles Found.
# Finding Articles of Author 30: Bullier, J (355046)
# 96 Articles Found.
# Finding Articles of Author 31: Bullinaria, JA (632546)
# 34 Articles Found.
# Finding Articles of Author 32: Bullock, D (7379844)
# 467 Articles Found.
# Finding Articles of Author 33: Bullock, S (11021299)
# 5 Articles Found.
# Finding Articles of Author 34: Bullot, NJ (2589859)
# 17 Articles Found.
# Finding Articles of Author 35: Bulthoff, HH (14457)
# 515 Articles Found.
# Finding Articles of Author 36: Bundesen, C (275051)
# 117 Articles Found.
# Finding Articles of Author 37: Burani, C (465273)
# 82 Articles Found.
# Finding Articles of Author 38: Burgdorf, J (729070)
# 58 Articles Found.
# Finding Articles of Author 39: Burgess, GC (2029503)
# 30 Articles Found.
# Finding Articles of Author 40: Burgess, N (26981)
# 173 Articles Found.
# Finding Articles of Author 41: Burgess, RL (793730)
# 50 Articles Found.
# Finding Articles of Author 42: Burgmer, P (4810520)
# 18 Articles Found.
# Finding Articles of Author 43: Burgos, JE (1565126)
# 30 Articles Found.
# Finding Articles of Author 44: Burgund, ED (1661618)
# 28 Articles Found.
# Finding Articles of Author 45: Burk, JA (30332469)
# 41 Articles Found.
# Finding Articles of Author 46: Burkart, JM (32026164)
# 12 Articles Found.
# Finding Articles of Author 47: Burkart, JM (402499)
# 92 Articles Found.
# Finding Articles of Author 48: Burke, D (574946)
# 62 Articles Found.
# Finding Articles of Author 49: Burling, R (28174754)
# 15 Articles Found.
# Finding Articles of Author 50: Burne, THJ (181143)
# 172 Articles Found.
# Finding Articles of Author 51: Burnham, D (275963)
# 87 Articles Found.
# Finding Articles of Author 52: Burnod, Y (297899)
# 41 Articles Found.
# Finding Articles of Author 53: Burns, JK (7137204)
# 86 Articles Found.
# Finding Articles of Author 54: Burns, M (13322521)
# 10 Articles Found.
# Finding Articles of Author 55: Burr, DC (23814)
# 241 Articles Found.
# Finding Articles of Author 56: Burt, SA (35042148)
# 244 Articles Found.
# Finding Articles of Author 57: Burton, AM (35233964)
# 12 Articles Found.
# Finding Articles of Author 58: Burton, AW (155114)
# 165 Articles Found.
# Finding Articles of Author 59: Burton, GA (4602295)
# 65 Articles Found.
# Finding Articles of Author 60: Burwell, RD (613400)
# 54 Articles Found.
# Finding Articles of Author 61: Buscema, M (35568144)
# 137 Articles Found.
# Finding Articles of Author 62: Busemeyer, J (30702865)
# 10 Articles Found.
# Finding Articles of Author 63: Busemeyer, JR (161447)
# 156 Articles Found.
# Finding Articles of Author 64: Bushman, BJ (103672)
# 241 Articles Found.
# Finding Articles of Author 65: Buskell, A (34929775)
# 5 Articles Found.
# Finding Articles of Author 66: Buskell, A (4491301)
# 11 Articles Found.
# Finding Articles of Author 67: Butler, AB (282665)
# 102 Articles Found.
# Finding Articles of Author 68: Butler, DJ (4428959)
# 21 Articles Found.
# Finding Articles of Author 69: Butner, JE (40889625)
# 4 Articles Found.
# Finding Articles of Author 70: Butterfill, SA (1486600)
# 31 Articles Found.
# Finding Articles of Author 71: Butterworth, B (192753)
# 109 Articles Found.
# Finding Articles of Author 72: Button, KS (986434)
# 45 Articles Found.
# Finding Articles of Author 73: Buturovic, Z (31670772)
# 4 Articles Found.
# Finding Articles of Author 74: Buturovic, Z (4908409)
# 9 Articles Found.
# Finding Articles of Author 75: Buunk, AP (261147)
# 127 Articles Found.
# Finding Articles of Author 76: Buxbaum, LJ (315173)
# 101 Articles Found.
# Finding Articles of Author 77: Bybee, J (1592341)
# 25 Articles Found.
# Finding Articles of Author 78: Byrne, A (668328)
# 58 Articles Found.
# Finding Articles of Author 79: Bzdok, D (861530)
# 81 Articles Found.
# Finding Articles of Author 80: CAELLI, T (112378)
# 179 Articles Found.
# Finding Articles of Author 81: CAIRNS, RB (300695)
# 112 Articles Found.
# Finding Articles of Author 82: CALABRESE, RL (35155856)
# 126 Articles Found.
# Finding Articles of Author 83: CALANCIE, B (11413295)
# 13 Articles Found.
# Finding Articles of Author 84: CALDER, WA (28125709)
# 79 Articles Found.
# Finding Articles of Author 85: CALDWELL, BM (6369924)
# 14 Articles Found.
# Finding Articles of Author 86: CALLAWAY, E (17532181)
# 141 Articles Found.
# Finding Articles of Author 87: CALLEN, CR (4798840)
# 8 Articles Found.
# Finding Articles of Author 88: CAMERON, L (7493781)
# 6 Articles Found.
# Finding Articles of Author 89: CAMHI, JM (752515)
# 69 Articles Found.
# Finding Articles of Author 90: CAMMANN, R (2342819)
# 20 Articles Found.
# Finding Articles of Author 91: CAMPBELL, CBG (395348)
# 130 Articles Found.
# Finding Articles of Author 92: CAMPBELL, DT (258451)
# 170 Articles Found.
# Finding Articles of Author 93: CAMPBELL, K (28262761)
# 4 Articles Found.
# Finding Articles of Author 94: CAMPBELL, R (33174491)
# 1 Articles Found.
# Finding Articles of Author 95: CAMPBELL, R (37448952)
# 2 Articles Found.
# Finding Articles of Author 96: CAMPBELL, RL (2772184)
# 97 Articles Found.
# Finding Articles of Author 97: CANCRO, R (35835605)
# 155 Articles Found.
# Finding Articles of Author 98: CANDLAND, DK (557664)
# 75 Articles Found.
# Finding Articles of Author 99: CANNON, TD (11982721)
# 43 Articles Found.
# Finding Articles of Author 100: CAPADAY, C (740768)
# b'Authenticated (SID: C292psIUxnIFCTgkRua)'
# 40 Articles Found.
# Finding Articles of Author 101: CAPITANIO, JP (35826950)
# 61 Articles Found.
# Finding Articles of Author 102: CAPLAN, A (10402768)
# 7 Articles Found.
# Finding Articles of Author 103: CAPLAN, AL (35798307)
# 309 Articles Found.
# Finding Articles of Author 104: CAPRON, C (2196407)
# 16 Articles Found.
# Finding Articles of Author 105: CAPUTA, M (629097)
# 57 Articles Found.
# Finding Articles of Author 106: CARACO, T (459795)
# 70 Articles Found.
# Finding Articles of Author 107: CARASSA, A (2149904)
# 14 Articles Found.
# Finding Articles of Author 108: CARBONELL, JG (4151706)
# 24 Articles Found.
# Finding Articles of Author 109: CARD, SK (1386398)
# 18 Articles Found.
# Finding Articles of Author 110: CARELLO, C (310311)
# 68 Articles Found.
# Finding Articles of Author 111: CAREY, G (4073447)
# 14 Articles Found.
# Finding Articles of Author 112: CARLETON, LR (3908707)
# 10 Articles Found.
# Finding Articles of Author 113: CARLIER, M (2380309)
# 39 Articles Found.
# Finding Articles of Author 114: CARLSON, JS (2816902)
# 30 Articles Found.
# Finding Articles of Author 115: CARLSON, M (4218441)
# 19 Articles Found.
# Finding Articles of Author 116: CARLSON, NR (1341271)
# 28 Articles Found.
# Finding Articles of Author 117: CARLSONRADVANSKY, LA (15736)
# 35 Articles Found.
# Finding Articles of Author 118: CARLSSON, A (907499)
# 48 Articles Found.
# Finding Articles of Author 119: CARLSSON, M (616963)
# 99 Articles Found.
# Finding Articles of Author 120: CARMON, A (36217996)
# 6 Articles Found.
# Finding Articles of Author 121: CARNAHAN, H (23801045)
# 28 Articles Found.
# Finding Articles of Author 122: CAROLAN, TF (4120937)
# 4 Articles Found.
# Finding Articles of Author 123: CARONPARGUE, J (5806207)
# 6 Articles Found.
# Finding Articles of Author 124: CARR, EG (328077)
# 84 Articles Found.
# Finding Articles of Author 125: CARROLL, JB (225416)
# 148 Articles Found.
# Finding Articles of Author 126: CARROLL, JM (86126)
# 198 Articles Found.
# Finding Articles of Author 127: CARSTON, R (1318611)
# 32 Articles Found.
# Finding Articles of Author 128: CARTMILL, M (1783460)
# 28 Articles Found.
# Finding Articles of Author 129: CASAGRANDE, VA (200871)
# 156 Articles Found.
# Finding Articles of Author 130: CASPARI, EW (899934)
# 45 Articles Found.
# Finding Articles of Author 131: CASPER, RC (310797)
# 104 Articles Found.
# Finding Articles of Author 132: CASPI, A (18633)
# 395 Articles Found.
# Finding Articles of Author 133: CASSADAY, HJ (419465)
# 95 Articles Found.
# Finding Articles of Author 134: CASSEL, JC (1037713)
# 126 Articles Found.
# Finding Articles of Author 135: CASSIDY, KW (2285360)
# 19 Articles Found.
# Finding Articles of Author 136: CASTONGUAY, TW (3426704)
# 51 Articles Found.
# Finding Articles of Author 137: CATON, H (1502198)
# 14 Articles Found.
# Finding Articles of Author 138: CATTELL, RB (17836)
# 461 Articles Found.
# Finding Articles of Author 139: CAVALLARI, P (382899)
# 107 Articles Found.
# Finding Articles of Author 140: CAVANAGH, PR (24273)
# 250 Articles Found.
# Finding Articles of Author 141: CAVONIUS, CR (397982)
# 95 Articles Found.
# Finding Articles of Author 142: CAWS, P (28151127)
# 21 Articles Found.
# Finding Articles of Author 143: CERNACEK, J (1402714)
# 34 Articles Found.
# Finding Articles of Author 144: CERVERO, F (116966)
# 201 Articles Found.
# Finding Articles of Author 145: CESPUGLIO, R (36133297)
# 31 Articles Found.
# Finding Articles of Author 146: CHACON, G (4572399)
# 10 Articles Found.
# Finding Articles of Author 147: CHAIKA, E (2139534)
# 17 Articles Found.
# Finding Articles of Author 148: CHALMERS, DJ (473426)
# 153 Articles Found.
# Finding Articles of Author 149: CHALMERS, NR (1816798)
# 30 Articles Found.
# Finding Articles of Author 150: CHALUPA, LM (228469)
# 146 Articles Found.
# Finding Articles of Author 151: CHAMBERS, JK (27820225)
# 74 Articles Found.
# Finding Articles of Author 152: CHANDLER, M (5316899)
# 15 Articles Found.
# Finding Articles of Author 153: CHANDRASEKARAN, B (1242730)
# 86 Articles Found.
# Finding Articles of Author 154: CHANGEUX, JP (8175)
# 726 Articles Found.
# Finding Articles of Author 155: CHAPMAN, JP (579800)
# 99 Articles Found.
# Finding Articles of Author 156: CHAPMAN, LJ (73865)
# 138 Articles Found.
# Finding Articles of Author 157: CHAPMAN, RM (1219236)
# 25 Articles Found.
# Finding Articles of Author 158: CHAPPLE, WD (1467629)
# 33 Articles Found.
# Finding Articles of Author 159: CHARLESWORTH, WR (1159769)
# 41 Articles Found.
# Finding Articles of Author 160: CHARNIAK, E (1121961)
# 21 Articles Found.
# Finding Articles of Author 161: CHARNOV, EL (205367)
# 153 Articles Found.
# Finding Articles of Author 162: CHASE, ID (1951277)
# 26 Articles Found.
# Finding Articles of Author 163: CHASE, PG (1733796)
# 21 Articles Found.
# Finding Articles of Author 164: CHASE, WG (1788389)
# 26 Articles Found.
# Finding Articles of Author 165: CHASIOTIS, A (1054435)
# 35 Articles Found.
# Finding Articles of Author 166: CHASTAIN, G (18674355)
# 15 Articles Found.
# Finding Articles of Author 167: CHATTERJEE, A (38388940)
# 9 Articles Found.
# Finding Articles of Author 168: CHAURASIA, BD (1258804)
# 37 Articles Found.
# Finding Articles of Author 169: CHAVAJAY, P (3327346)
# 13 Articles Found.
# Finding Articles of Author 170: CHEESMAN, J (2620868)
# 12 Articles Found.
# Finding Articles of Author 171: CHEKALUK, E (1798875)
# 28 Articles Found.
# Finding Articles of Author 172: CHERKIN, A (470346)
# 85 Articles Found.
# Finding Articles of Author 173: CHERNIAK, C (28252772)
# 7 Articles Found.
# Finding Articles of Author 174: CHERTOK, L (594411)
# 72 Articles Found.
# Finding Articles of Author 175: CHESS, S (325628)
# 71 Articles Found.
# Finding Articles of Author 176: CHEVALIERSKOLNIKOFF, S (2234215)
# 20 Articles Found.
# Finding Articles of Author 177: CHEVERUD, JM (55928)
# 244 Articles Found.
# Finding Articles of Author 178: CHHIBBER, SR (7747451)
# 6 Articles Found.
# Finding Articles of Author 179: CHI, MTH (26357922)
# 8 Articles Found.
# Finding Articles of Author 180: CHIANG, L (20651773)
# 4 Articles Found.
# Finding Articles of Author 181: CHILD, IL (453771)
# 84 Articles Found.
# Finding Articles of Author 182: CHIPMAN, SF (2144714)
# 19 Articles Found.
# Finding Articles of Author 183: CHISELIN, MT (33998102)
# 1 Articles Found.
# Finding Articles of Author 184: CHISZAR, DA (164798)
# 173 Articles Found.
# Finding Articles of Author 185: CHOI, EJ (359237)
# 115 Articles Found.
# Finding Articles of Author 186: CHOMSKY, N (24926794)
# 38 Articles Found.
# Finding Articles of Author 187: CHOW, KL (30508231)
# 6 Articles Found.
# Finding Articles of Author 188: CHOW, SL (2708608)
# 13 Articles Found.
# Finding Articles of Author 189: CHUA, R (112777)
# 190 Articles Found.
# Finding Articles of Author 190: CHUBIN, DE (248644)
# 131 Articles Found.
# Finding Articles of Author 191: CHURCH, RM (155946)
# 179 Articles Found.
# Finding Articles of Author 192: CHURCHLAND, PM (500090)
# 54 Articles Found.
# Finding Articles of Author 193: CHURCHLAND, PS (358526)
# 77 Articles Found.
# Finding Articles of Author 194: CHUTE, DL (617218)
# 76 Articles Found.
# Finding Articles of Author 195: CICCHETTI, DV (108408)
# 223 Articles Found.
# Finding Articles of Author 196: CINQUE, G (28283660)
# 4 Articles Found.
# Finding Articles of Author 197: CIOFFI, F (1205602)
# 44 Articles Found.
# Finding Articles of Author 198: CLARAC, F (118661)
# 211 Articles Found.
# Finding Articles of Author 199: CLARIDGE, G (12076011)
# 23 Articles Found.
# Finding Articles of Author 200: CLARK, A (11913604)
# b'Authenticated (SID: D6gETGqMe3hQswNNwXE)'
# 3 Articles Found.
# Finding Articles of Author 201: CLARK, A (12388960)
# 3 Articles Found.
# Finding Articles of Author 202: CLARK, A (26137748)
# 1 Articles Found.
# Finding Articles of Author 203: CLARK, AB (1047140)
# 51 Articles Found.
# Finding Articles of Author 204: CLARK, AS (16726108)
# 27 Articles Found.
# Finding Articles of Author 205: CLARK, CW (4128596)
# 150 Articles Found.
# Finding Articles of Author 206: CLARK, FJ (233331)
# 103 Articles Found.
# Finding Articles of Author 207: CLARK, HH (629958)
# 78 Articles Found.
# Finding Articles of Author 208: CLARK, JM (2671270)
# 32 Articles Found.
# Finding Articles of Author 209: CLARK, SJ (28198746)
# 10 Articles Found.
# Finding Articles of Author 210: CLARK, WC (645155)
# 145 Articles Found.
# Finding Articles of Author 211: CLARKE, AM (189865)
# 134 Articles Found.
# Finding Articles of Author 212: CLARKE, PGH (2666566)
# 170 Articles Found.
# Finding Articles of Author 213: CLAVIER, RA (25069801)
# 2 Articles Found.
# Finding Articles of Author 214: CLAYTON, P (19452637)
# 16 Articles Found.
# Finding Articles of Author 215: CLEGHORN, JM (536758)
# 83 Articles Found.
# Finding Articles of Author 216: CLELAND, CE (1647692)
# 27 Articles Found.
# Finding Articles of Author 217: CLOAK, FT (5392576)
# 7 Articles Found.
# Finding Articles of Author 218: CLYNES, M (21152045)
# 37 Articles Found.
# Finding Articles of Author 219: COHEN, A (31130925)
# 1 Articles Found.
# Finding Articles of Author 220: COHEN, AH (3806721)
# 22 Articles Found.
# Finding Articles of Author 221: COHEN, BD (1657641)
# 78 Articles Found.
# Finding Articles of Author 222: COHEN, G (1020564)
# 25 Articles Found.
# Finding Articles of Author 223: COHEN, LG (7347913)
# 406 Articles Found.
# Finding Articles of Author 224: COHEN, LJ (11231843)
# 87 Articles Found.
# Finding Articles of Author 225: COHEN, LJ (28170085)
# 43 Articles Found.
# Finding Articles of Author 226: COHEN, LJ (734032)
# 161 Articles Found.
# Finding Articles of Author 227: COHEN, MS (8389579)
# 44 Articles Found.
# Finding Articles of Author 228: COHEN, N (177957)
# 91 Articles Found.
# Finding Articles of Author 229: COHEN, RM (122719)
# 216 Articles Found.
# Finding Articles of Author 230: COHEN, S (33139892)
# 1 Articles Found.
# Finding Articles of Author 231: COLBY, CL (971943)
# 53 Articles Found.
# Finding Articles of Author 232: COLBY, KM (1049801)
# 42 Articles Found.
# Finding Articles of Author 233: COLE, S (1751449)
# 28 Articles Found.
# Finding Articles of Author 234: COLGAN, P (30562599)
# 6 Articles Found.
# Finding Articles of Author 235: COLLET, W (2517182)
# 17 Articles Found.
# Finding Articles of Author 236: COLLINS, BJ (3148061)
# 26 Articles Found.
# Finding Articles of Author 237: COLLINS, GC (35911378)
# 29 Articles Found.
# Finding Articles of Author 238: COLLINS, HM (72221)
# 162 Articles Found.
# Finding Articles of Author 239: COLLINS, JK (751553)
# 78 Articles Found.
# Finding Articles of Author 240: COLLINS, RL (5487573)
# 182 Articles Found.
# Finding Articles of Author 241: COMER, CM (918130)
# 39 Articles Found.
# Finding Articles of Author 242: COMMISSARIS, RL (372170)
# 101 Articles Found.
# Finding Articles of Author 243: CONE, JD (1176800)
# 45 Articles Found.
# Finding Articles of Author 244: CONNELL, JP (2697248)
# 63 Articles Found.
# Finding Articles of Author 245: CONNOLLY, CI (1459211)
# 15 Articles Found.
# Finding Articles of Author 246: CONNOLLY, JF (79142)
# 93 Articles Found.
# Finding Articles of Author 247: CONNOLLY, KJ (1778664)
# 103 Articles Found.
# Finding Articles of Author 248: CONRAD, J (9052929)
# 9 Articles Found.
# Finding Articles of Author 249: CONTRERASVIDAL, JL (266250)
# 107 Articles Found.
# Finding Articles of Author 250: CONTRERASVIDAL, JL (35824927)
# 7 Articles Found.
# Finding Articles of Author 251: COOK, M (38020944)
# 1 Articles Found.
# Finding Articles of Author 252: COOLS, AR (26138)
# 429 Articles Found.
# Finding Articles of Author 253: COOMBS, D (5092505)
# 17 Articles Found.
# Finding Articles of Author 254: COOPER, BY (32789831)
# 41 Articles Found.
# Finding Articles of Author 255: COOPER, LA (36424809)
# 9 Articles Found.
# Finding Articles of Author 256: COOPER, PR (3583538)
# 208 Articles Found.
# Finding Articles of Author 257: COOPER, WE (1407)
# 1029 Articles Found.
# Finding Articles of Author 258: CORCORAN, TA (3771079)
# 12 Articles Found.
# Finding Articles of Author 259: CORDRAY, DS (1511280)
# 31 Articles Found.
# Finding Articles of Author 260: CORDS, M (511632)
# 88 Articles Found.
# Finding Articles of Author 261: CORLEY, KC (1045875)
# 44 Articles Found.
# Finding Articles of Author 262: CORNE, C (2242395)
# 17 Articles Found.
# Finding Articles of Author 263: CORNELL, EH (1173538)
# 38 Articles Found.
# Finding Articles of Author 264: CORNER, MA (368907)
# 94 Articles Found.
# Finding Articles of Author 265: CORNING, PA (915785)
# 43 Articles Found.
# Finding Articles of Author 266: CORSON, DW (519879)
# 79 Articles Found.
# Finding Articles of Author 267: CORTEEN, RS (3489110)
# 13 Articles Found.
# Finding Articles of Author 268: CORTER, JE (1135464)
# 32 Articles Found.
# Finding Articles of Author 269: CORWIN, TR (978650)
# 47 Articles Found.
# Finding Articles of Author 270: COSCINA, DV (294095)
# 121 Articles Found.
# Finding Articles of Author 271: COSTA, PT (47812)
# 320 Articles Found.
# Finding Articles of Author 272: COSTEFF, H (794801)
# 56 Articles Found.
# Finding Articles of Author 273: COTTERILL, RMJ (544304)
# 94 Articles Found.
# Finding Articles of Author 274: COTTRELL, GW (303195)
# 64 Articles Found.
# Finding Articles of Author 275: COWEY, A (46326)
# 213 Articles Found.
# Finding Articles of Author 276: COWIE, RJ (807314)
# 60 Articles Found.
# Finding Articles of Author 277: CRAGO, PE (359595)
# 77 Articles Found.
# Finding Articles of Author 278: CRAMMOND, DJ (369857)
# 110 Articles Found.
# Finding Articles of Author 279: CRANDALL, R (8612038)
# 54 Articles Found.
# Finding Articles of Author 280: CRASKE, B (1102561)
# 42 Articles Found.
# Finding Articles of Author 281: CRAWFORD, C (6969702)
# 15 Articles Found.
# Finding Articles of Author 282: CRAWFORD, JM (28206831)
# 27 Articles Found.
# Finding Articles of Author 283: CRAWFORD, M (4374473)
# 8 Articles Found.
# Finding Articles of Author 284: CREWTHER, DP (35831622)
# 122 Articles Found.
# Finding Articles of Author 285: CRICK, F (2266276)
# 21 Articles Found.
# Finding Articles of Author 286: CRIDER, A (3503455)
# 23 Articles Found.
# Finding Articles of Author 287: CROCKETT, LJ (393690)
# 61 Articles Found.
# Finding Articles of Author 288: CROMER, RF (1913832)
# 25 Articles Found.
# Finding Articles of Author 289: CROMWELL, RL (240778)
# 100 Articles Found.
# Finding Articles of Author 290: CROTHERS, C (20499738)
# 4 Articles Found.
# Finding Articles of Author 291: CROUCH, RK (21961)
# 435 Articles Found.
# Finding Articles of Author 292: CROUCHER, M (30661885)
# 3 Articles Found.
# Finding Articles of Author 293: CROW, JF (107421)
# 233 Articles Found.
# Finding Articles of Author 294: CROW, JF (1138768)
# 31 Articles Found.
# Finding Articles of Author 295: CROWDER, RG (382552)
# 98 Articles Found.
# Finding Articles of Author 296: CROWLEY, MJ (10084435)
# 12 Articles Found.
# Finding Articles of Author 297: CRUSE, H (28126376)
# 99 Articles Found.
# Finding Articles of Author 298: CRUTCHER, KA (29452607)
# 153 Articles Found.
# Finding Articles of Author 299: CRUTCHER, MD (1401036)
# 22 Articles Found.
# Finding Articles of Author 300: CSANYI, V (31793258)
# b'Authenticated (SID: E614vPxMtAg7tetHPus)'
# 8 Articles Found.
# Finding Articles of Author 301: CUMMINS, R (18134755)
# 29 Articles Found.
# Finding Articles of Author 302: CUNNINGHAM, MA (1507357)
# 27 Articles Found.
# Finding Articles of Author 303: CUNNINGHAM, MA (2447573)
# 26 Articles Found.
# Finding Articles of Author 304: CURRIE, C (8710668)
# 7 Articles Found.
# Finding Articles of Author 305: CUSSINS, A (6456824)
# 2 Articles Found.
# Finding Articles of Author 306: CYNX, J (1428742)
# 33 Articles Found.
# Finding Articles of Author 307: CZIGLER, I (216962)
# 133 Articles Found.
# Finding Articles of Author 308: CZYZEWSKA, M (5674755)
# 10 Articles Found.
# Finding Articles of Author 309: Cabanac, M (28134953)
# 258 Articles Found.
# Finding Articles of Author 310: Cabe, PA (763962)
# 62 Articles Found.
# Finding Articles of Author 311: Cabello, R (1527828)
# 34 Articles Found.
# Finding Articles of Author 312: Cabib, S (196034)
# 134 Articles Found.
# Finding Articles of Author 313: Cacace, AT (406753)
# 90 Articles Found.
# Finding Articles of Author 314: Cachel, S (892340)
# 16 Articles Found.
# Finding Articles of Author 315: Cacioppo, JT (26562)
# 445 Articles Found.
# Finding Articles of Author 316: Cacioppo, S (888055)
# 57 Articles Found.
# Finding Articles of Author 317: Cahen, A (41137705)
# 3 Articles Found.
# Finding Articles of Author 318: Cahen, A (5536848)
# 8 Articles Found.
# Finding Articles of Author 319: Cahill, SP (894203)
# 44 Articles Found.
# Finding Articles of Author 320: Cai, HJ (857245)
# 62 Articles Found.
# Finding Articles of Author 321: Cai, ZGG (2500664)
# 20 Articles Found.
# Finding Articles of Author 322: Cain, DP (297462)
# 119 Articles Found.
# Finding Articles of Author 323: Cajar, A (6080198)
# 6 Articles Found.
# Finding Articles of Author 324: Calabresi, P (19849)
# 537 Articles Found.
# Finding Articles of Author 325: Caldara, R (181488)
# 32 Articles Found.
# Finding Articles of Author 326: Calder, AJ (31758036)
# 166 Articles Found.
# Finding Articles of Author 327: Caldwell, CA (934326)
# 43 Articles Found.
# Finding Articles of Author 328: Calhoun, PS (147174)
# 206 Articles Found.
# Finding Articles of Author 329: Caligiore, D (1391581)
# 27 Articles Found.
# Finding Articles of Author 330: Call, J (37480775)
# 78 Articles Found.
# Finding Articles of Author 331: Call, J (38213)
# 310 Articles Found.
# Finding Articles of Author 332: Callender, C (1472470)
# 26 Articles Found.
# Finding Articles of Author 333: Callender, C (36203976)
# 18 Articles Found.
# Finding Articles of Author 334: Caluser, I (9948268)
# 3 Articles Found.
# Finding Articles of Author 335: Calvin, WH (832421)
# 51 Articles Found.
# Finding Articles of Author 336: Calvo, P (35231597)
# 15 Articles Found.
# Finding Articles of Author 337: Camerer, C (4522758)
# 51 Articles Found.
# Finding Articles of Author 338: Camerer, CF (159813)
# 123 Articles Found.
# Finding Articles of Author 339: Cameron, CD (1978832)
# 32 Articles Found.
# Finding Articles of Author 340: Cameron, J (28945392)
# 9 Articles Found.
# Finding Articles of Author 341: Cameron, K (29883088)
# 11 Articles Found.
# Finding Articles of Author 342: Caminiti, R (1716049)
# 42 Articles Found.
# Finding Articles of Author 343: Campbell, A (23316787)
# 2 Articles Found.
# Finding Articles of Author 344: Campbell, A (5326886)
# 20 Articles Found.
# Finding Articles of Author 345: Campbell, A (700785)
# 64 Articles Found.
# Finding Articles of Author 346: Campbell, JID (576319)
# 51 Articles Found.
# Finding Articles of Author 347: Campbell, K (33829384)
# 1 Articles Found.
# Finding Articles of Author 348: Campbell, R (639702)
# 81 Articles Found.
# Finding Articles of Author 349: Campbell, T (264564)
# 19 Articles Found.
# Finding Articles of Author 350: Campbell, TG (31218705)
# 15 Articles Found.
# Finding Articles of Author 351: Campion, J (1989563)
# 28 Articles Found.
# Finding Articles of Author 352: Campitelli, A (37999764)
# 1 Articles Found.
# Finding Articles of Author 353: Campos, R (2553015)
# 16 Articles Found.
# Finding Articles of Author 354: Camus, V (190391)
# 72 Articles Found.
# Finding Articles of Author 355: Canal-Bruland, R (545167)
# 89 Articles Found.
# Finding Articles of Author 356: Cangelosi, A (179480)
# 91 Articles Found.
# Finding Articles of Author 357: Cann, R (2623255)
# 13 Articles Found.
# Finding Articles of Author 358: Cantalupo, C (1217807)
# 35 Articles Found.
# Finding Articles of Author 359: Cantero, JL (29951201)
# 127 Articles Found.
# Finding Articles of Author 360: Cantlon, JF (784035)
# 59 Articles Found.
# Finding Articles of Author 361: Capaldi, EJ (206055)
# 151 Articles Found.
# Finding Articles of Author 362: Caplan, D (1670633)
# 92 Articles Found.
# Finding Articles of Author 363: Caplan, D (98319)
# 91 Articles Found.
# Finding Articles of Author 364: Caporael, LR (1118903)
# 40 Articles Found.
# Finding Articles of Author 365: Cappa, SF (21165)
# 487 Articles Found.
# Finding Articles of Author 366: Cappelen, AW (17450057)
# 7 Articles Found.
# Finding Articles of Author 367: Cappello, G (11176014)
# 4 Articles Found.
# Finding Articles of Author 368: Caramazza, A (37167)
# 395 Articles Found.
# Finding Articles of Author 369: Carbon, CC (92925)
# 275 Articles Found.
# Finding Articles of Author 370: Cardaciotto, L (3253891)
# 13 Articles Found.
# Finding Articles of Author 371: Cardel, MI (1312769)
# 57 Articles Found.
# Finding Articles of Author 372: Cardena, E (384525)
# 72 Articles Found.
# Finding Articles of Author 373: Cardinal, CD (11002050)
# 3 Articles Found.
# Finding Articles of Author 374: Carey, D (8297517)
# 7 Articles Found.
# Finding Articles of Author 375: Carey, DP (436965)
# 74 Articles Found.
# Finding Articles of Author 376: Carey, S (177074)
# 81 Articles Found.
# Finding Articles of Author 377: Carlo, G (224628)
# 154 Articles Found.
# Finding Articles of Author 378: Carlson, A (301068)
# 30 Articles Found.
# Finding Articles of Author 379: Carlson, G (10319599)
# 21 Articles Found.
# Finding Articles of Author 380: Carlson, RA (587294)
# 131 Articles Found.
# Finding Articles of Author 381: Carlton, LG (485402)
# 88 Articles Found.
# Finding Articles of Author 382: Carmichael, HL (2269769)
# 23 Articles Found.
# Finding Articles of Author 383: Carnes, NC (5160478)
# 8 Articles Found.
# Finding Articles of Author 384: Caro, T (326454)
# 116 Articles Found.
# Finding Articles of Author 385: Carpendale, JIM (669567)
# 64 Articles Found.
# Finding Articles of Author 386: Carpenter, AC (6162900)
# 7 Articles Found.
# Finding Articles of Author 387: Carpenter, GA (457641)
# 48 Articles Found.
# Finding Articles of Author 388: Carpenter, JP (35797261)
# 251 Articles Found.
# Finding Articles of Author 389: Carpenter, M (399029)
# 90 Articles Found.
# Finding Articles of Author 390: Carr, JH (28159233)
# 15 Articles Found.
# Finding Articles of Author 391: Carr, TH (35803856)
# 127 Articles Found.
# Finding Articles of Author 392: Carrasco, X (1837699)
# 28 Articles Found.
# Finding Articles of Author 393: Carre, R (1217323)
# 42 Articles Found.
# Finding Articles of Author 394: Carreiras, M (80110)
# 255 Articles Found.
# Finding Articles of Author 395: Carrera, P (31446257)
# 46 Articles Found.
# Finding Articles of Author 396: Carrier, J (36259)
# 237 Articles Found.
# Finding Articles of Author 397: Carroll, BT (694177)
# 71 Articles Found.
# Finding Articles of Author 398: Carroll, KA (5323182)
# 9 Articles Found.
# Finding Articles of Author 399: Carroll, SE (2386593)
# 29 Articles Found.
# Finding Articles of Author 400: Carroll, TD (36136166)
# b'Authenticated (SID: D1YYM5GEqMLQmxzQ2F6)'
# 14 Articles Found.
# Finding Articles of Author 401: Carruthers, P (368736)
# 81 Articles Found.
# Finding Articles of Author 402: Carsel, T (10524696)
# 3 Articles Found.
# Finding Articles of Author 403: Carstairs-McCarthy, A (1608578)
# 33 Articles Found.
# Finding Articles of Author 404: Carter, CS (24067)
# 262 Articles Found.
# Finding Articles of Author 405: Carter, EC (2101677)
# 19 Articles Found.
# Finding Articles of Author 406: Carter, OL (569556)
# 55 Articles Found.
# Finding Articles of Author 407: Cartoni, E (5262616)
# 6 Articles Found.
# Finding Articles of Author 408: Cartwright, R (290508)
# 37 Articles Found.
# Finding Articles of Author 409: Caruana, F (1713395)
# 32 Articles Found.
# Finding Articles of Author 410: Caruso, EM (1676590)
# 34 Articles Found.
# Finding Articles of Author 411: Carver, CS (31462)
# 414 Articles Found.
# Finding Articles of Author 412: Casale, MB (3726601)
# 15 Articles Found.
# Finding Articles of Author 413: Casartelli, L (2762662)
# 13 Articles Found.
# Finding Articles of Author 414: Case, DA (13702)
# 441 Articles Found.
# Finding Articles of Author 415: Casebeer, WD (2306165)
# 9 Articles Found.
# Finding Articles of Author 416: Casey, MB (30378066)
# 15 Articles Found.
# Finding Articles of Author 417: Casey, MB (605645)
# 33 Articles Found.
# Finding Articles of Author 418: Cashdan, E (36072730)
# 29 Articles Found.
# Finding Articles of Author 419: Cassidy, S (792006)
# 27 Articles Found.
# Finding Articles of Author 420: Castaldi, E (2442653)
# 12 Articles Found.
# Finding Articles of Author 421: Castel, A (30312576)
# 100 Articles Found.
# Finding Articles of Author 422: Castelfranchi, C (231642)
# 87 Articles Found.
# Finding Articles of Author 423: Castellanos, FX (39446)
# 354 Articles Found.
# Finding Articles of Author 424: Castelo-Branco, M (303637)
# 312 Articles Found.
# Finding Articles of Author 425: Castiello, U (36341351)
# 62 Articles Found.
# Finding Articles of Author 426: Castro, L (1177720)
# 33 Articles Found.
# Finding Articles of Author 427: Catania, AC (30308716)
# 127 Articles Found.
# Finding Articles of Author 428: Cathiard, MA (1911329)
# 21 Articles Found.
# Finding Articles of Author 429: Catmur, C (648270)
# 88 Articles Found.
# Finding Articles of Author 430: Cavallero, C (2448469)
# 28 Articles Found.
# Finding Articles of Author 431: Cavanagh, P (21222366)
# 188 Articles Found.
# Finding Articles of Author 432: Cave, KR (497362)
# 76 Articles Found.
# Finding Articles of Author 433: Ceci, SJ (104264)
# 202 Articles Found.
# Finding Articles of Author 434: Cellini, N (35130276)
# 10 Articles Found.
# Finding Articles of Author 435: Centorrino, S (4573872)
# 8 Articles Found.
# Finding Articles of Author 436: Chabris, CF (460262)
# 96 Articles Found.
# Finding Articles of Author 437: Chacon, DA (30527942)
# 5 Articles Found.
# Finding Articles of Author 438: Chakrabarti, B (35200008)
# 111 Articles Found.
# Finding Articles of Author 439: Chalmers, M (15871868)
# 8 Articles Found.
# Finding Articles of Author 440: Chalmers, M (183505)
# 74 Articles Found.
# Finding Articles of Author 441: Chamberlain, R (3316031)
# 21 Articles Found.
# Finding Articles of Author 442: Chambers, C (2152615)
# 45 Articles Found.
# Finding Articles of Author 443: Chambers, JR (1306375)
# 29 Articles Found.
# Finding Articles of Author 444: Chambers, KC (5098153)
# 74 Articles Found.
# Finding Articles of Author 445: Chambers, RA (382960)
# 93 Articles Found.
# Finding Articles of Author 446: Chambres, P (1851383)
# 22 Articles Found.
# Finding Articles of Author 447: Chaminade, T (993460)
# 45 Articles Found.
# Finding Articles of Author 448: Chan, JCK (1455393)
# 34 Articles Found.
# Finding Articles of Author 449: Chan, S (13556811)
# 3 Articles Found.
# Finding Articles of Author 450: Chan, W (3036927)
# 13 Articles Found.
# Finding Articles of Author 451: Chandler, J (1330900)
# 22 Articles Found.
# Finding Articles of Author 452: Chandrasekharan, S (1744307)
# 22 Articles Found.
# Finding Articles of Author 453: Chang, B (1582173)
# 24 Articles Found.
# Finding Articles of Author 454: Chang, C (22470696)
# 1 Articles Found.
# Finding Articles of Author 455: Chang, F (1384626)
# 37 Articles Found.
# Finding Articles of Author 456: Chang, L (29669515)
# 58 Articles Found.
# Finding Articles of Author 457: Chang, LJ (1625290)
# 32 Articles Found.
# Finding Articles of Author 458: Chang, N (30260161)
# 4 Articles Found.
# Finding Articles of Author 459: Chang, S (8576351)
# 3 Articles Found.
# Finding Articles of Author 460: Chang, SWC (3577164)
# 64 Articles Found.
# Finding Articles of Author 461: Chang, W (14511872)
# 1 Articles Found.
# Finding Articles of Author 462: Changizi, MA (1348476)
# 33 Articles Found.
# Finding Articles of Author 463: Chapais, B (1046638)
# 42 Articles Found.
# Finding Articles of Author 464: Chapman, CR (290275)
# 128 Articles Found.
# Finding Articles of Author 465: Chapman, P (1442221)
# 51 Articles Found.
# Finding Articles of Author 466: Chapman, RM (998597)
# 36 Articles Found.
# Finding Articles of Author 467: Chappell, J (1323984)
# 34 Articles Found.
# Finding Articles of Author 468: Charland, LC (1392522)
# 28 Articles Found.
# Finding Articles of Author 469: Charles, E (1365721)
# 23 Articles Found.
# Finding Articles of Author 470: Charlton, BG (137833)
# 251 Articles Found.
# Finding Articles of Author 471: Charman, T (67123)
# 342 Articles Found.
# Finding Articles of Author 472: Charness, N (247304)
# 110 Articles Found.
# Finding Articles of Author 473: Charney, DS (3397)
# 869 Articles Found.
# Finding Articles of Author 474: Charney, E (778978)
# 17 Articles Found.
# Finding Articles of Author 475: Chatelle, C (27937835)
# 94 Articles Found.
# Finding Articles of Author 476: Chater, N (18870195)
# 83 Articles Found.
# Finding Articles of Author 477: Chater, N (74308)
# 128 Articles Found.
# Finding Articles of Author 478: Chatterjee, A (6198268)
# 29 Articles Found.
# Finding Articles of Author 479: Chaturvedi, V (28909942)
# 9 Articles Found.
# Finding Articles of Author 480: Chatzikyriakidis, S (2978633)
# 11 Articles Found.
# Finding Articles of Author 481: Chauvet, GA (1580930)
# 55 Articles Found.
# Finding Articles of Author 482: Cheke, LG (1889596)
# 28 Articles Found.
# Finding Articles of Author 483: Chella, A (84268)
# 63 Articles Found.
# Finding Articles of Author 484: Chemero, A (655267)
# 56 Articles Found.
# Finding Articles of Author 485: Chemero, T (23286488)
# 1 Articles Found.
# Finding Articles of Author 486: Chemla, E (30102402)
# 62 Articles Found.
# Finding Articles of Author 487: Chen, BB (29703796)
# 84 Articles Found.
# Finding Articles of Author 488: Chen, EE (2064408)
# 13 Articles Found.
# Finding Articles of Author 489: Chen, EE (29780577)
# 9 Articles Found.
# Finding Articles of Author 490: Chen, FS (1657444)
# 37 Articles Found.
# Finding Articles of Author 491: Chen, HC (703333)
# 67 Articles Found.
# Finding Articles of Author 492: Chen, IP (2891655)
# 12 Articles Found.
# Finding Articles of Author 493: Chen, J (33774005)
# 21 Articles Found.
# Finding Articles of Author 494: Chen, JY (3144215)
# 15 Articles Found.
# Finding Articles of Author 495: Chen, NC (4537944)
# 4 Articles Found.
# Finding Articles of Author 496: Chen, SD (36370950)
# 11 Articles Found.
# Finding Articles of Author 497: Cheney, DL (36923)
# 162 Articles Found.
# Finding Articles of Author 498: Cheng, GHL (2655785)
# 21 Articles Found.
# Finding Articles of Author 499: Cheng, JT (2523499)
# 22 Articles Found.
# Finding Articles of Author 500: Cheng, K (227721)
# b'Authenticated (SID: D3vSwvs4PqzmDwZqRrP)'
# 143 Articles Found.
# Finding Articles of Author 501: Cheng, PCH (881396)
# 31 Articles Found.
# Finding Articles of Author 502: Cheng, PW (924213)
# 44 Articles Found.
# Finding Articles of Author 503: Cheng, S (1589357)
# 31 Articles Found.
# Finding Articles of Author 504: Cheng, S (32131430)
# 2 Articles Found.
# Finding Articles of Author 505: Cheon, BK (2172312)
# 37 Articles Found.
# Finding Articles of Author 506: Chernyak, N (3296275)
# 20 Articles Found.
# Finding Articles of Author 507: Cherrett, T (684445)
# 62 Articles Found.
# Finding Articles of Author 508: Cheshire, A (28188604)
# 9 Articles Found.
# Finding Articles of Author 509: Chesney-Lind, M (1402258)
# 47 Articles Found.
# Finding Articles of Author 510: Chesnokova, O (5742257)
# 11 Articles Found.
# Finding Articles of Author 511: Chetverikov, A (2033188)
# 40 Articles Found.
# Finding Articles of Author 512: Cheung, CN (3706073)
# 12 Articles Found.
# Finding Articles of Author 513: Chevalley, C (2953130)
# 15 Articles Found.
# Finding Articles of Author 514: Chevallier, C (966461)
# 50 Articles Found.
# Finding Articles of Author 515: Cheyne, JA (411698)
# 90 Articles Found.
# Finding Articles of Author 516: Chiang, C (21447148)
# 1 Articles Found.
# Finding Articles of Author 517: Chiang, WC (1540122)
# 31 Articles Found.
# Finding Articles of Author 518: Chiao, JY (536274)
# 66 Articles Found.
# Finding Articles of Author 519: Chiappe, DL (1326048)
# 28 Articles Found.
# Finding Articles of Author 520: Chieffi, S (603292)
# 46 Articles Found.
# Finding Articles of Author 521: Chiesa, M (18996442)
# 11 Articles Found.
# Finding Articles of Author 522: Chikazoe, J (1462465)
# 35 Articles Found.
# Finding Articles of Author 523: Chisholm, JS (814575)
# 85 Articles Found.
# Finding Articles of Author 524: Chittka, L (114292)
# 218 Articles Found.
# Finding Articles of Author 525: Cho, SY (12560728)
# 2 Articles Found.
# Finding Articles of Author 526: Choe, JC (459618)
# 55 Articles Found.
# Finding Articles of Author 527: Choe, Y (487706)
# 21 Articles Found.
# Finding Articles of Author 528: Choi, D (12835034)
# 5 Articles Found.
# Finding Articles of Author 529: Choi, VK (9790856)
# 6 Articles Found.
# Finding Articles of Author 530: Choi, YY (3787224)
# 15 Articles Found.
# Finding Articles of Author 531: Chokron, S (252557)
# 135 Articles Found.
# Finding Articles of Author 532: Choo, JJ (10142010)
# 7 Articles Found.
# Finding Articles of Author 533: Choshen-Hillel, S (3686831)
# 16 Articles Found.
# Finding Articles of Author 534: Chou, IH (2155528)
# 22 Articles Found.
# Finding Articles of Author 535: Chouinard-Thuly, L (5314411)
# 9 Articles Found.
# Finding Articles of Author 536: Chow, SL (1784335)
# 18 Articles Found.
# Finding Articles of Author 537: Chowdhury, A (29135145)
# 11 Articles Found.
# Finding Articles of Author 538: Chowdhury, SM (1883111)
# 25 Articles Found.
# Finding Articles of Author 539: Chown, E (2863731)
# 5 Articles Found.
# Finding Articles of Author 540: Chrisley, RL (2615132)
# 14 Articles Found.
# Finding Articles of Author 541: Christensen, SE (28191005)
# 10 Articles Found.
# Finding Articles of Author 542: Christensen, W (37236165)
# 3 Articles Found.
# Finding Articles of Author 543: Christensen, WD (2342250)
# 19 Articles Found.
# Finding Articles of Author 544: Christiansen, H (695180)
# 84 Articles Found.
# Finding Articles of Author 545: Christiansen, MH (234241)
# 112 Articles Found.
# Finding Articles of Author 546: Christiansen, P (701370)
# 93 Articles Found.
# Finding Articles of Author 547: Christiansena, MH (17286205)
# 1 Articles Found.
# Finding Articles of Author 548: Christianson, K (863273)
# 50 Articles Found.
# Finding Articles of Author 549: Christie, CD (7212135)
# 16 Articles Found.
# Finding Articles of Author 550: Christie, MA (1287049)
# 26 Articles Found.
# Finding Articles of Author 551: Christie, S (4396659)
# 11 Articles Found.
# Finding Articles of Author 552: Christie, T (6527717)
# 7 Articles Found.
# Finding Articles of Author 553: Christopoulos, GI (35197775)
# 36 Articles Found.
# Finding Articles of Author 554: Chubb, C (185867)
# 136 Articles Found.
# Finding Articles of Author 555: Chudek, M (3692871)
# 11 Articles Found.
# Finding Articles of Author 556: Chung, STL (310380)
# 141 Articles Found.
# Finding Articles of Author 557: Church, J (3247267)
# 19 Articles Found.
# Finding Articles of Author 558: Cian, L (3198881)
# 8 Articles Found.
# Finding Articles of Author 559: Cichocka, A (1341447)
# 39 Articles Found.
# Finding Articles of Author 560: Cicogna, PC (1272780)
# 21 Articles Found.
# Finding Articles of Author 561: Cimpian, A (971863)
# 60 Articles Found.
# Finding Articles of Author 562: Cipolli, C (433543)
# 88 Articles Found.
# Finding Articles of Author 563: Cirelli, C (135178)
# 120 Articles Found.
# Finding Articles of Author 564: Cisek, P (766815)
# 48 Articles Found.
# Finding Articles of Author 565: Civai, C (3634595)
# 14 Articles Found.
# Finding Articles of Author 566: Clahsen, H (226589)
# 96 Articles Found.
# Finding Articles of Author 567: Claidiere, N (1639301)
# 33 Articles Found.
# Finding Articles of Author 568: Clancey, WJ (658653)
# 49 Articles Found.
# Finding Articles of Author 569: Clancy, B (2146474)
# 15 Articles Found.
# Finding Articles of Author 570: Clapin, H (3566452)
# 12 Articles Found.
# Finding Articles of Author 571: Clark, A (10513894)
# 2 Articles Found.
# Finding Articles of Author 572: Clark, A (17562531)
# 2 Articles Found.
# Finding Articles of Author 573: Clark, A (35985612)
# 2 Articles Found.
# Finding Articles of Author 574: Clark, A (39026753)
# 1 Articles Found.
# Finding Articles of Author 575: Clark, A (8998698)
# 1 Articles Found.
# Finding Articles of Author 576: Clark, C (10343382)
# 8 Articles Found.
# Finding Articles of Author 577: Clark, CJ (3909258)
# 19 Articles Found.
# Finding Articles of Author 578: Clark, JJ (382970)
# 32 Articles Found.
# Finding Articles of Author 579: Clark, JM (635364)
# 85 Articles Found.
# Finding Articles of Author 580: Clark, KB (1522889)
# 32 Articles Found.
# Finding Articles of Author 581: Clark, KJ (2290958)
# 38 Articles Found.
# Finding Articles of Author 582: Clark, MS (29452668)
# 102 Articles Found.
# Finding Articles of Author 583: Clark, S (287064)
# 90 Articles Found.
# Finding Articles of Author 584: Clarke, DD (35813351)
# 72 Articles Found.
# Finding Articles of Author 585: Clarke, RW (31760974)
# 156 Articles Found.
# Finding Articles of Author 586: Clarke, S (989073)
# 41 Articles Found.
# Finding Articles of Author 587: Clarke, TL (2069527)
# 42 Articles Found.
# Finding Articles of Author 588: Clayton, N (52656)
# 280 Articles Found.
# Finding Articles of Author 589: Cleeremans, A (173970)
# 167 Articles Found.
# Finding Articles of Author 590: Clegg, BA (1218900)
# 37 Articles Found.
# Finding Articles of Author 591: Clegg, JM (3727114)
# 16 Articles Found.
# Finding Articles of Author 592: Cleland, CL (2006892)
# 33 Articles Found.
# Finding Articles of Author 593: Clement, CA (1716502)
# 26 Articles Found.
# Finding Articles of Author 594: Clement, F (1332325)
# 46 Articles Found.
# Finding Articles of Author 595: Clements, CC (3161351)
# 19 Articles Found.
# Finding Articles of Author 596: Cleret de Langavant, L (26535113)
# 24 Articles Found.
# Finding Articles of Author 597: Clevenger, J (2628075)
# 17 Articles Found.
# Finding Articles of Author 598: Clewett, D (2374596)
# 22 Articles Found.
# Finding Articles of Author 599: Clibbens, J (1894003)
# 12 Articles Found.
# Finding Articles of Author 600: Clifton, C (121234)
# b'Authenticated (SID: F1u3V4zkmTOIKEcttIP)'
# 108 Articles Found.
# Finding Articles of Author 601: Clissa, PJ (12390712)
# 4 Articles Found.
# Finding Articles of Author 602: Clore, GL (448320)
# 83 Articles Found.
# Finding Articles of Author 603: Clune, M (6234126)
# 1 Articles Found.
# Finding Articles of Author 604: Coall, DA (1413302)
# 39 Articles Found.
# Finding Articles of Author 605: Cocchi, M (35641423)
# 59 Articles Found.
# Finding Articles of Author 606: Cocea, M (772196)
# 19 Articles Found.
# Finding Articles of Author 607: Coch, D (1050324)
# 44 Articles Found.
# Finding Articles of Author 608: Code, C (48516)
# 258 Articles Found.
# Finding Articles of Author 609: Coderre, TJ (227655)
# 139 Articles Found.
# Finding Articles of Author 610: Coelho, RC (31816197)
# 31 Articles Found.
# Finding Articles of Author 611: Coello, Y (264631)
# 126 Articles Found.
# Finding Articles of Author 612: Coenen, A (102924)
# 176 Articles Found.
# Finding Articles of Author 613: Coghill, DR (113514)
# 258 Articles Found.
# Finding Articles of Author 614: Cohen, AB (2409268)
# 16 Articles Found.
# Finding Articles of Author 615: Cohen, AB (363439)
# 120 Articles Found.
# Finding Articles of Author 616: Cohen, D (169069)
# 197 Articles Found.
# Finding Articles of Author 617: Cohen, D (30426934)
# 9 Articles Found.
# Finding Articles of Author 618: Cohen, DB (4135654)
# 13 Articles Found.
# Finding Articles of Author 619: Cohen, DJ (1061631)
# 56 Articles Found.
# Finding Articles of Author 620: Cohen, G (8025620)
# 16 Articles Found.
# Finding Articles of Author 621: Cohen, H (3320875)
# 11 Articles Found.
# Finding Articles of Author 622: Cohen, J (26727259)
# 3 Articles Found.
# Finding Articles of Author 623: Cohen, J (32925161)
# 1 Articles Found.
# Finding Articles of Author 624: Cohen, JD (1897068)
# 283 Articles Found.
# Finding Articles of Author 625: Cohen, L (175346)
# 163 Articles Found.
# Finding Articles of Author 626: Cohen, N (1939315)
# 20 Articles Found.
# Finding Articles of Author 627: Cohen, NJ (95675)
# 250 Articles Found.
# Finding Articles of Author 628: Cohen, SL (1267435)
# 146 Articles Found.
# Finding Articles of Author 629: Cokely, ET (870949)
# 45 Articles Found.
# Finding Articles of Author 630: Colagiuri, B (779214)
# 72 Articles Found.
# Finding Articles of Author 631: Colantonio, J (35525694)
# 1 Articles Found.
# Finding Articles of Author 632: Colarelli, SM (1079597)
# 43 Articles Found.
# Finding Articles of Author 633: Cole, J (230416)
# 106 Articles Found.
# Finding Articles of Author 634: Cole, J (30348480)
# 26 Articles Found.
# Finding Articles of Author 635: Cole, J (37533539)
# 1 Articles Found.
# Finding Articles of Author 636: Cole, JC (2448701)
# 79 Articles Found.
# Finding Articles of Author 637: Cole, JC (950503)
# 28 Articles Found.
# Finding Articles of Author 638: Cole, S (2972310)
# 16 Articles Found.
# Finding Articles of Author 639: Coleman, G (89148)
# 136 Articles Found.
# Finding Articles of Author 640: Coleman, M (12319433)
# 5 Articles Found.
# Finding Articles of Author 641: Coles, MGH (157057)
# 103 Articles Found.
# Finding Articles of Author 642: Coles, NA (4740622)
# 6 Articles Found.
# Finding Articles of Author 643: Colgin, LL (1003594)
# 52 Articles Found.
# Finding Articles of Author 644: Colic, MV (34399205)
# 10 Articles Found.
# Finding Articles of Author 645: Colin, C (1077431)
# 44 Articles Found.
# Finding Articles of Author 646: Collaer, ML (2653247)
# 18 Articles Found.
# Finding Articles of Author 647: Colleran, H (3754755)
# 17 Articles Found.
# Finding Articles of Author 648: Collerton, D (643980)
# 68 Articles Found.
# Finding Articles of Author 649: Collier, J (4515151)
# 43 Articles Found.
# Finding Articles of Author 650: Collins, CE (1310515)
# 40 Articles Found.
# Finding Articles of Author 651: Collins, PF (639657)
# 56 Articles Found.
# Finding Articles of Author 652: Collins, T (789931)
# 61 Articles Found.
# Finding Articles of Author 653: Colman, AM (158118)
# 116 Articles Found.
# Finding Articles of Author 654: Colom, R (223749)
# 147 Articles Found.
# Finding Articles of Author 655: Colombetti, G (1919775)
# 22 Articles Found.
# Finding Articles of Author 656: Colombo, M (723588)
# 52 Articles Found.
# Finding Articles of Author 657: Colombo, M (858566)
# 67 Articles Found.
# Finding Articles of Author 658: Colonius, H (365562)
# 95 Articles Found.
# Finding Articles of Author 659: Coltheart, M (42398)
# 327 Articles Found.
# Finding Articles of Author 660: Commins, S (749935)
# 60 Articles Found.
# Finding Articles of Author 661: Commons, ML (29115319)
# 20 Articles Found.
# ...
# Finding Articles of Author 884: DELGADO, JMR (35794834)
# 51 Articles Found.
# Finding Articles of Author 885: DELIUS, JD (30309286)
# 123 Articles Found.
# Finding Articles of Author 886: DELLAROSA, D (5749712)
# 7 Articles Found.
# Finding Articles of Author 887: DELONG, MR (1497488)
# 30 Articles Found.
# Finding Articles of Author 888: DELONG, MR (66496)
# 241 Articles Found.
# Finding Articles of Author 889: DELPRATO, DJ (439827)
# 92 Articles Found.
# Finding Articles of Author 890: DEMAREST, WJ (8907821)
# 3 Articles Found.
# Finding Articles of Author 891: DEMOPOULOS, W (8213992)
# 11 Articles Found.
# Finding Articles of Author 892: DEMOREST, ME (1613993)
# 4 Articles Found.
# Finding Articles of Author 893: DEMSKI, LS (633470)
# 66 Articles Found.
# Finding Articles of Author 894: DENNETT, D (17640548)
# 7 Articles Found.
# Finding Articles of Author 895: DENNIS, RG (351589)
# 78 Articles Found.
# Finding Articles of Author 896: DENUYL, MJ (6014613)
# 3 Articles Found.
# Finding Articles of Author 897: DERAM, SC (8518839)
# 2 Articles Found.
# Finding Articles of Author 898: DERIVERA, J (20759367)
# 22 Articles Found.
# Finding Articles of Author 899: DERRICKSON, KC (3772383)
# 12 Articles Found.
# Finding Articles of Author 900: DESIMONE, R (44160)
# b'Authenticated (SID: C4qxvtyF7BUmYw27l3d)'
# 156 Articles Found.
# Finding Articles of Author 901: DESOUSA, R (17711463)
# 4 Articles Found.
# Finding Articles of Author 902: DEUEL, RK (764174)
# 60 Articles Found.
# Finding Articles of Author 903: DEUTSCH, JA (46331)
# 113 Articles Found.
# Finding Articles of Author 904: DEV, P (23283959)
# 5 Articles Found.
# Finding Articles of Author 905: DEVILLIER, J (12610477)
# 3 Articles Found.
# Finding Articles of Author 906: DEVRIES, PH (4298290)
# 18 Articles Found.
# Finding Articles of Author 907: DEWAN, EM (773728)
# 65 Articles Found.
# Finding Articles of Author 908: DEWEERT, CMM (2530923)
# 33 Articles Found.
# Finding Articles of Author 909: DEWIED, D (2407907)
# 56 Articles Found.
# Finding Articles of Author 910: DEWSBURY, DA (57833)
# 312 Articles Found.
# Finding Articles of Author 911: DIACONIS, P (8679413)
# 51 Articles Found.
# Finding Articles of Author 912: DIAMOND, IT (47729)
# 111 Articles Found.
# Finding Articles of Author 913: DIAMOND, M (30429044)
# 7 Articles Found.
# Finding Articles of Author 914: DIAMOND, MC (35801247)
# 110 Articles Found.
# Finding Articles of Author 915: DICARLO, JJ (767880)
# 60 Articles Found.
# Finding Articles of Author 916: DICHGANS, J (21474)
# 294 Articles Found.
# Finding Articles of Author 917: DICKEMANN, M (3278671)
# 13 Articles Found.
# Finding Articles of Author 918: DICKINSON, BW (3593588)
# 8 Articles Found.
# Finding Articles of Author 919: DICKINSON, J (21415010)
# 44 Articles Found.
# Finding Articles of Author 920: DIDOMENICO, R (13391964)
# 13 Articles Found.
# Finding Articles of Author 921: DIEDERICH, J (6253617)
# 7 Articles Found.
# Finding Articles of Author 922: DIENSKE, H (1347572)
# 34 Articles Found.
# Finding Articles of Author 923: DIETTERICH, TG (35804627)
# 56 Articles Found.
# Finding Articles of Author 924: DIETZ, V (29828)
# 176 Articles Found.
# Finding Articles of Author 925: DIGGLES, VA (5288123)
# 7 Articles Found.
# Finding Articles of Author 926: DILOLLO, V (35852149)
# 147 Articles Found.
# Finding Articles of Author 927: DIMOND, SJ (826871)
# 69 Articles Found.
# Finding Articles of Author 928: DIMSDALE, JE (13476)
# 601 Articles Found.
# Finding Articles of Author 929: DINGWALL, WO (2958933)
# 16 Articles Found.
# Finding Articles of Author 930: DINSMOOR, JA (482705)
# 82 Articles Found.
# Finding Articles of Author 931: DISCALA, G (762205)
# 68 Articles Found.
# Finding Articles of Author 932: DISMUKES, K (1774017)
# 26 Articles Found.
# Finding Articles of Author 933: DISMUKES, RK (1943268)
# 26 Articles Found.
# Finding Articles of Author 934: DITTRICH, WH (555082)
# 51 Articles Found.
# Finding Articles of Author 935: DIVAC, I (322177)
# 110 Articles Found.
# Finding Articles of Author 936: DIXON, NF (745071)
# 61 Articles Found.
# Finding Articles of Author 937: DODD, D (1557444)
# 31 Articles Found.
# Finding Articles of Author 938: DODWELL, PC (406257)
# 106 Articles Found.
# Finding Articles of Author 939: DOHERTY, ME (484808)
# 75 Articles Found.
# Finding Articles of Author 940: DOLHINOW, P (2276055)
# 21 Articles Found.
# Finding Articles of Author 941: DOMESHEK, E (6077542)
# 3 Articles Found.
# Finding Articles of Author 942: DOMOTOR, Z (36911377)
# 5 Articles Found.
# Finding Articles of Author 943: DONAHOE, JW (605075)
# 58 Articles Found.
# Finding Articles of Author 944: DONALD, M (10702856)
# 14 Articles Found.
# Finding Articles of Author 945: DONALD, M (11238354)
# 6 Articles Found.
# Finding Articles of Author 946: DONALD, MW (497444)
# 38 Articles Found.
# Finding Articles of Author 947: DONER, JF (30558533)
# 5 Articles Found.
# Finding Articles of Author 948: DONNELLEY, S (1677760)
# 30 Articles Found.
# Finding Articles of Author 949: DONNELLY, N (36192181)
# 18 Articles Found.
# Finding Articles of Author 950: DOOB, LW (509476)
# 66 Articles Found.
# Finding Articles of Author 951: DORE, FY (293809)
# 74 Articles Found.
# Finding Articles of Author 952: DORFMAN, DD (405334)
# 75 Articles Found.
# Finding Articles of Author 953: DOTY, RW (234050)
# 136 Articles Found.
# Finding Articles of Author 954: DOUGHERTY, GG (5088989)
# 14 Articles Found.
# Finding Articles of Author 955: DOUGLAS, JD (1805831)
# 28 Articles Found.
# Finding Articles of Author 956: DOUGLAS, RJ (1383249)
# 21 Articles Found.
# Finding Articles of Author 957: DOURISH, CT (90696)
# 249 Articles Found.
# Finding Articles of Author 958: DOW, MM (1245934)
# 38 Articles Found.
# Finding Articles of Author 959: DOWNES, SM (35221125)
# 25 Articles Found.
# Finding Articles of Author 960: DOWNS, RM (664776)
# 59 Articles Found.
# Finding Articles of Author 961: DOYLE, AJR (2864355)
# 21 Articles Found.
# Finding Articles of Author 962: DOYLE, J (1723700)
# 20 Articles Found.
# Finding Articles of Author 963: DOYLE, JR (1112181)
# 74 Articles Found.
# Finding Articles of Author 964: DRAKE, RA (1263778)
# 40 Articles Found.
# Finding Articles of Author 965: DRATZ, EA (115554)
# 210 Articles Found.
# Finding Articles of Author 966: DREIFUSS, JJ (119108)
# 211 Articles Found.
# Finding Articles of Author 967: DRESHER, BE (1634832)
# 23 Articles Found.
# Finding Articles of Author 968: DRETSKE, F (767001)
# 50 Articles Found.
# Finding Articles of Author 969: DREYFUS, HL (91314)
# 203 Articles Found.
# Finding Articles of Author 970: DREYFUS, SE (793240)
# 39 Articles Found.
# Finding Articles of Author 971: DUBNER, R (53892)
# 153 Articles Found.
# Finding Articles of Author 972: DUDAR, JD (3026358)
# 14 Articles Found.
# Finding Articles of Author 973: DUDEK, B (28382702)
# 2 Articles Found.
# Finding Articles of Author 974: DUDLEY, RM (10585999)
# 32 Articles Found.
# Finding Articles of Author 975: DUFFY, CJ (508010)
# 80 Articles Found.
# Finding Articles of Author 976: DUFOUR, R (31870985)
# 9 Articles Found.
# Finding Articles of Author 977: DUGATKIN, LA (305841)
# 117 Articles Found.
# Finding Articles of Author 978: DUHAMEL, JR (496177)
# 81 Articles Found.
# Finding Articles of Author 979: DUKE, MP (803493)
# 52 Articles Found.
# Finding Articles of Author 980: DUMFORD, J (12381310)
# 2 Articles Found.
# Finding Articles of Author 981: DUMMETT, M (4654461)
# 8 Articles Found.
# Finding Articles of Author 982: DUNBAR, K (1274090)
# 37 Articles Found.
# Finding Articles of Author 983: DUNCAN, J (35182640)
# 138 Articles Found.
# Finding Articles of Author 984: DUNN, AJ (27861285)
# 51 Articles Found.
# Finding Articles of Author 985: DUNNETT, SB (13770)
# 594 Articles Found.
# Finding Articles of Author 986: DURLACH, NI (277629)
# 118 Articles Found.
# Finding Articles of Author 987: DUTTA, A (3682151)
# 10 Articles Found.
# Finding Articles of Author 988: DUYME, M (4661108)
# 23 Articles Found.
# Finding Articles of Author 989: DUYSENS, J (27876065)
# 67 Articles Found.
# Finding Articles of Author 990: DWORKIN, B (1063121)
# 46 Articles Found.
# Finding Articles of Author 991: DYBVIG, M (5179917)
# 8 Articles Found.
# Finding Articles of Author 992: DYDEWALLE, G (333794)
# 70 Articles Found.
# Finding Articles of Author 993: DYER, AB (3759867)
# 18 Articles Found.
# Finding Articles of Author 994: DYKES, RW (286847)
# 126 Articles Found.
# Finding Articles of Author 995: DZHAFAROV, EN (35841007)
# 34 Articles Found.
# Finding Articles of Author 996: Daan, S (122317)
# 209 Articles Found.
# Finding Articles of Author 997: Daffertshofer, A (198834)
# 151 Articles Found.
# Finding Articles of Author 998: Dahl, A (1467762)
# 40 Articles Found.
# Finding Articles of Author 999: Dakanalis, A (35201291)
# 93 Articles Found.
# Finding Articles of Author 1000: Dale, R (12958646)
# b'Authenticated (SID: E2v1r36Mo3gQHQUD6rx)'
# 72 Articles Found.
# Finding Articles of Author 1001: Dale, R (310912)
# 39 Articles Found.
# Finding Articles of Author 1002: Dalenoort, GJ (2823435)
# 15 Articles Found.
# Finding Articles of Author 1003: Dalgleish, T (120505)
# 209 Articles Found.
# Finding Articles of Author 1004: Dalgleish, T (40480076)
# 26 Articles Found.
# Finding Articles of Author 1005: Dalile, B (19004479)
# 4 Articles Found.
# Finding Articles of Author 1006: Dall, SRX (655250)
# 62 Articles Found.
# Finding Articles of Author 1007: Dalla Barba, G (35347624)
# 44 Articles Found.
# Finding Articles of Author 1008: Dallacker, M (5398937)
# 8 Articles Found.
# Finding Articles of Author 1009: Dallman, MF (54906)
# 78 Articles Found.
# Finding Articles of Author 1010: Dalrymple-Aford, JC (26744853)
# 1 Articles Found.
# Finding Articles of Author 1011: Daly, M (325425)
# 82 Articles Found.
# Finding Articles of Author 1012: Daly, M (35945063)
# 7 Articles Found.
# Finding Articles of Author 1013: Damasio, AR (59069)
# 254 Articles Found.
# Finding Articles of Author 1014: Dambacher, M (1066748)
# 26 Articles Found.
# Finding Articles of Author 1015: Damper, RI (250599)
# 77 Articles Found.
# Finding Articles of Author 1016: Dana, J (1252560)
# 36 Articles Found.
# Finding Articles of Author 1017: Dandurand, F (2124079)
# 15 Articles Found.
# Finding Articles of Author 1018: Dang, J (30363166)
# 25 Articles Found.
# Finding Articles of Author 1019: Daniel, H (9432491)
# 27 Articles Found.
# Finding Articles of Author 1020: Daniel, SG (5172371)
# 17 Articles Found.
# Finding Articles of Author 1021: Danielson, DK (5490908)
# 7 Articles Found.
# Finding Articles of Author 1022: Danielson, P (1432996)
# 23 Articles Found.
# Finding Articles of Author 1023: Danks, D (675957)
# 39 Articles Found.
# Finding Articles of Author 1024: Dannemiller, JL (615119)
# 72 Articles Found.
# Finding Articles of Author 1025: Danovitch, JH (30399901)
# 14 Articles Found.
# Finding Articles of Author 1026: Dar, R (326227)
# 42 Articles Found.
# Finding Articles of Author 1027: Dar-Nimrod, I (1368062)
# 44 Articles Found.
# Finding Articles of Author 1028: Darley, J (233374)
# 121 Articles Found.
# Finding Articles of Author 1029: Darlington, RB (858627)
# 53 Articles Found.
# Finding Articles of Author 1030: Dartnall, T (28189647)
# 8 Articles Found.
# Finding Articles of Author 1031: Dassonville, PR (18960454)
# 6 Articles Found.
# Finding Articles of Author 1032: Datteri, E (3300420)
# 11 Articles Found.
# Finding Articles of Author 1033: Dauce, E (2888971)
# 10 Articles Found.
# Finding Articles of Author 1034: Daum, MM (649336)
# 62 Articles Found.
# Finding Articles of Author 1035: Davalos, DB (34639542)
# 55 Articles Found.
# Finding Articles of Author 1036: Davey, GCL (184829)
# 124 Articles Found.
# Finding Articles of Author 1037: David, AS (4787)
# 857 Articles Found.
# Finding Articles of Author 1038: Davidoff, J (277717)
# 70 Articles Found.
# Finding Articles of Author 1039: Davidoff, J (28126751)
# 54 Articles Found.
# Finding Articles of Author 1040: Davids, K (55579)
# 335 Articles Found.
# Finding Articles of Author 1041: Davidson, JW (903255)
# 58 Articles Found.
# Finding Articles of Author 1042: Davidson, K (2324458)
# 46 Articles Found.
# Finding Articles of Author 1043: Davidson, RE (2224371)
# 32 Articles Found.
# Finding Articles of Author 1044: Davies, IRL (284935)
# 108 Articles Found.
# Finding Articles of Author 1045: Davies, KM (3990570)
# 12 Articles Found.
# Finding Articles of Author 1046: Davies, M (25614353)
# 1 Articles Found.
# Finding Articles of Author 1047: Davies, N (35889589)
# 69 Articles Found.
# Finding Articles of Author 1048: Davies, PS (2516978)
# 32 Articles Found.
# Finding Articles of Author 1049: Davies, S (35209187)
# 140 Articles Found.
# Finding Articles of Author 1050: Davies, T (435391)
# 4 Articles Found.
# Finding Articles of Author 1051: Davies, TN (6239925)
# 6 Articles Found.
# Finding Articles of Author 1052: Davies, W (113958)
# 51 Articles Found.
# Finding Articles of Author 1053: Davies, WM (32202565)
# 15 Articles Found.
# Finding Articles of Author 1054: Davis, BL (539648)
# 64 Articles Found.
# Finding Articles of Author 1055: Davis, CJ (676823)
# 49 Articles Found.
# Finding Articles of Author 1056: Davis, CP (2908483)
# 18 Articles Found.
# Finding Articles of Author 1057: Davis, E (893613)
# 36 Articles Found.
# Finding Articles of Author 1058: Davis, G (8827543)
# 3 Articles Found.
# Finding Articles of Author 1059: Davis, G (932966)
# 37 Articles Found.
# Finding Articles of Author 1060: Davis, H (547625)
# 52 Articles Found.
# Finding Articles of Author 1061: Davis, HP (406489)
# 123 Articles Found.
# Finding Articles of Author 1062: Davis, J (3871923)
# 17 Articles Found.
# Finding Articles of Author 1063: Davis, M (40984731)
# 1 Articles Found.
# Finding Articles of Author 1064: Davis, MH (329183)
# 106 Articles Found.
# Finding Articles of Author 1065: Davis, OSP (537474)
# 75 Articles Found.
# Finding Articles of Author 1066: Davis, T (3673008)
# 14 Articles Found.
# Finding Articles of Author 1067: Davis, V (11830559)
# 5 Articles Found.
# Finding Articles of Author 1068: Dawson, A (34913862)
# 14 Articles Found.
# Finding Articles of Author 1069: Dawson, M (4402043)
# 22 Articles Found.
# Finding Articles of Author 1070: Dawson, ME (131817)
# 182 Articles Found.
# Finding Articles of Author 1071: Dawson, MRW (196785)
# 55 Articles Found.
# Finding Articles of Author 1072: Day, RH (81485)
# 211 Articles Found.
# Finding Articles of Author 1073: Day, RL (35516080)
# 8 Articles Found.
# Finding Articles of Author 1074: Dayton, CJ (1288193)
# 33 Articles Found.
# Finding Articles of Author 1075: De Brigard, F (977972)
# 62 Articles Found.
# Finding Articles of Author 1076: De Corte, BJ (5144313)
# 22 Articles Found.
# Finding Articles of Author 1077: De Cruz, H (754682)
# 44 Articles Found.
# Finding Articles of Author 1078: De Dreu, CKW (31469086)
# 16 Articles Found.
# Finding Articles of Author 1079: De Graef, P (1152160)
# 45 Articles Found.
# Finding Articles of Author 1080: De Houwer, J (52841)
# 275 Articles Found.
# Finding Articles of Author 1081: De Lillo, C (36262410)
# 13 Articles Found.
# Finding Articles of Author 1082: De Neys, W (576311)
# 77 Articles Found.
# Finding Articles of Author 1083: De Smedt, J (703388)
# 25 Articles Found.
# Finding Articles of Author 1084: De Weerd, P (656964)
# 70 Articles Found.
# Finding Articles of Author 1085: De Young, R (866208)
# 59 Articles Found.
# Finding Articles of Author 1086: De la Sala, S (22410786)
# 1 Articles Found.
# Finding Articles of Author 1087: DeBruine, LM (159257)
# 201 Articles Found.
# Finding Articles of Author 1088: DeJesus, JM (2177861)
# 12 Articles Found.
# Finding Articles of Author 1089: DeJesus, R (7101894)
# 2 Articles Found.
# Finding Articles of Author 1090: DeJong, WP (7964446)
# 56 Articles Found.
# Finding Articles of Author 1091: DeKay, WT (33589526)
# 1 Articles Found.
# Finding Articles of Author 1092: DeLancey, C (2164004)
# 18 Articles Found.
# Finding Articles of Author 1093: DeLoache, JS (399808)
# 90 Articles Found.
# Finding Articles of Author 1094: DeLong, CM (3131196)
# 22 Articles Found.
# Finding Articles of Author 1095: DeMarree, KG (1268580)
# 35 Articles Found.
# Finding Articles of Author 1096: DeNigris, D (7262204)
# 14 Articles Found.
# Finding Articles of Author 1097: DePaul, R (3176307)
# 22 Articles Found.
# Finding Articles of Author 1098: DeScioli, P (1438434)
# 41 Articles Found.
# Finding Articles of Author 1099: DeWall, CN (235229)
# 140 Articles Found.
# Finding Articles of Author 1100: DeWind, NK (10902879)
# b'Authenticated (SID: D6i7ZxgMhD2Q31yUEJa)'
# 16 Articles Found.
# Finding Articles of Author 1101: DeYoung, CG (366721)
# 118 Articles Found.
# Finding Articles of Author 1102: DeZeeuw, CI (76249)
